# %%
import pandas as pd
import numpy as np
import random
import datetime

import plotly.express as px
import plotly.graph_objects as go

# %%
# 绘制子图
from plotly.subplots import make_subplots

# %%
# 时间
time_range = pd.date_range(start="2019/1/1", end="2021/12/31")
time_range
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25',
#                '2021-12-26', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31'],
#               dtype='datetime64[ns]', length=1096, freq='D')

# %%
len(time_range)
# Out:
# 1096

# %%
# 水果
fruits = ["香蕉", "苹果", "葡萄", "橙子", "哈密瓜", "芭乐", "梨", "桃子"]
fruits_list = np.random.choice(fruits, size = len(time_range), replace=True)
fruits_list
# Out:
# array(['葡萄', '哈密瓜', '葡萄', ..., '哈密瓜', '橙子', '葡萄'], dtype='<U3')

# %%
# 客户
names = ["Mike", "John", "Tom", "xiaoming", "Jimmy", "Lym", "Michk"]
names_list = np.random.choice(names, size = len(time_range), replace=True)
names_list
# Out:
# array(['John', 'John', 'Lym', ..., 'xiaoming', 'xiaoming', 'Mike'],
#       dtype='<U8')

# %%
# 生成订单数据
order = pd.DataFrame({
    "time": time_range,
    "fruit": fruits_list,
    "name": names_list,
    "kilogram": np.random.choice(list(range(50, 100)), size=len(time_range), replace=True)
})
order
# Out:
#            time fruit      name  kilogram
# 0    2019-01-01    葡萄      John        60
# 1    2019-01-02   哈密瓜      John        89
# 2    2019-01-03    葡萄       Lym        50
# 3    2019-01-04    橙子      Mike        61
# 4    2019-01-05    橙子       Lym        92
# ...         ...   ...       ...       ...
# 1091 2021-12-27    桃子       Tom        82
# 1092 2021-12-28    芭乐     Michk        60
# 1093 2021-12-29   哈密瓜  xiaoming        77
# 1094 2021-12-30    橙子  xiaoming        50
# 1095 2021-12-31    葡萄      Mike        59
#
# [1096 rows x 4 columns]

# %%
# 水果信息
information = pd.DataFrame({
    "fruit": fruits,
    "price": [3.8, 8.9, 12.8, 6.8, 15.8, 4.9, 5.8, 7],
    "region": ["华南", "华北", "西北", "华中", "西北", "华南", "华北", "华中"]
})
information
# Out:
#   fruit  price region
# 0    香蕉    3.8     华南
# 1    苹果    8.9     华北
# 2    葡萄   12.8     西北
# 3    橙子    6.8     华中
# 4   哈密瓜   15.8     西北
# 5    芭乐    4.9     华南
# 6     梨    5.8     华北
# 7    桃子    7.0     华中

# %%
# 数据合并
df = pd.merge(
    order,
    information,
    how="outer"
).sort_values("time").reset_index(drop=True)

df.head()
# Out:
#         time fruit  name  kilogram  price region
# 0 2019-01-01    葡萄  John        60   12.8     西北
# 1 2019-01-02   哈密瓜  John        89   15.8     西北
# 2 2019-01-03    葡萄   Lym        50   12.8     西北
# 3 2019-01-04    橙子  Mike        61    6.8     华中
# 4 2019-01-05    橙子   Lym        92    6.8     华中

# %%
# 生成订单金额字段
df["amount"] = df["kilogram"] * df["price"]

df.head()
# Out:
#         time fruit  name  kilogram  price region  amount
# 0 2019-01-01    葡萄  John        60   12.8     西北   768.0
# 1 2019-01-02   哈密瓜  John        89   15.8     西北  1406.2
# 2 2019-01-03    葡萄   Lym        50   12.8     西北   640.0
# 3 2019-01-04    橙子  Mike        61    6.8     华中   414.8
# 4 2019-01-05    橙子   Lym        92    6.8     华中   625.6

# %%
df1 = pd.pivot_table(
    df,
    index=pd.Grouper(key="time", freq="M"),
    values="kilogram",
    aggfunc=np.sum
).reset_index()

# df1["time"] = df1["time"].dt.strftime("%Y-%m")

fig1 = px.bar(df1, x="time", y = "kilogram", color="kilogram")
fig1.update_layout(xaxis_tickangle = 45, xaxis_tickformat = "%Y-%m")
fig1.show()

# %%
# 2019-2021年销售额走势
df2 = pd.pivot_table(
    df,
    index=pd.Grouper(key="time", freq="M"),
    values="amount",
    aggfunc=np.sum
).reset_index()

# %%
fig2 = px.line(
    df2,
    x = "time",
    y = "amount",
    markers = True,
    hover_data={"time": "|%Y年%m月"}
)

fig2.update_layout(
    xaxis_tickangle = 45,
    xaxis_tickformat = "%Y-%m",
    yaxis_tickformat = "0"
)
fig2.show()

# %%
# 年度销量、销售额和平均销售额

df3 = pd.pivot_table(
    df,
    index=pd.Grouper(key="time", freq="Y"),
    values=["kilogram", "amount"],
    aggfunc=np.sum
).reset_index()

# %%
df3["mean_amount"] = df3["amount"] / df3["kilogram"]
df3
# Out:
#         time    amount  kilogram  mean_amount
# 0 2019-12-31  231699.8     27121     8.543188
# 1 2020-12-31  227548.9     26914     8.454667
# 2 2021-12-31  231515.9     27594     8.390081

# %%
# 水果年度销量占比

df4 = pd.pivot_table(
    df,
    index=[pd.Grouper(key="time", freq="Y"), "fruit"],
    values=["kilogram", "amount"],
    aggfunc=np.sum
).reset_index()

df4["time"] = df4["time"].dt.strftime("%Y")
df4
# Out:
#     time fruit   amount  kilogram
# 0   2019   哈密瓜  65854.4      4168
# 1   2019    桃子  23254.0      3322
# 2   2019     梨  19760.6      3407
# 3   2019    橙子  23303.6      3427
# 4   2019    芭乐  13876.8      2832
# 5   2019    苹果  24065.6      2704
# 6   2019    葡萄  48345.6      3777
# 7   2019    香蕉  13239.2      3484
# 8   2020   哈密瓜  62125.6      3932
# 9   2020    桃子  25487.0      3641
# 10  2020     梨  17220.2      2969
# 11  2020    橙子  19006.0      2795
# 12  2020    芭乐  16522.8      3372
# 13  2020    苹果  33134.7      3723
# 14  2020    葡萄  41843.2      3269
# 15  2020    香蕉  12209.4      3213
# 16  2021   哈密瓜  57117.0      3615
# 17  2021    桃子  23352.0      3336
# 18  2021     梨  13502.4      2328
# 19  2021    橙子  24684.0      3630
# 20  2021    芭乐  15234.1      3109
# 21  2021    苹果  28533.4      3206
# 22  2021    葡萄  53030.4      4143
# 23  2021    香蕉  16062.6      4227

# %%
fig3 = make_subplots(
    rows=1, cols=3,
    subplot_titles=["2019年", "2020年", "2021年"],
    specs=[[{"type": "domain"}, {"type": "domain"}, {"type": "domain"}]]
)

years = df4["time"].unique().tolist()

for i, year in enumerate(years):
    name = df4[df4["time"] == year].fruit.tolist()
    value = df4[df4["time"] == year].kilogram.tolist()
    fig3.add_trace(
        go.Pie(
            labels = name,
            values = value
        ),
        row = 1, col = i + 1
    )

fig3.update_traces(
    textposition = "inside",
    textinfo = "percent+label",
    hole = 0.4,
    insidetextorientation = "radial",
    hoverinfo = "label+percent+name"
)

fig3.show()

# %%
for i, year in enumerate(years):
    df5 = df4[df4["time"] == year]
    fig4 = go.Figure(go.Treemap(
        labels = df5["fruit"].tolist(),
        parents = df5["time"].tolist(),
        values = df5["amount"].tolist(),
        textinfo = "label+value+percent root"
    ))
    fig4.show()

# %%
# 商品月度销量变化

df6 = pd.pivot_table(
    df,
    index=[pd.Grouper(key="time", freq="M"), "fruit"],
    values="amount",
    aggfunc=np.sum
).reset_index()

df6["time"] = df6["time"].dt.strftime("%Y-%m")
df6
# Out:
#         time fruit  amount
# 0    2019-01   哈密瓜  5008.6
# 1    2019-01    桃子  1001.0
# 2    2019-01     梨   852.6
# 3    2019-01    橙子  3495.2
# 4    2019-01    芭乐   769.3
# ..       ...   ...     ...
# 279  2021-12    橙子  3291.2
# 280  2021-12    芭乐   294.0
# 281  2021-12    苹果  2189.4
# 282  2021-12    葡萄  6668.8
# 283  2021-12    香蕉  1535.2
#
# [284 rows x 3 columns]

# %%
fig5 = px.bar(
    df6,
    x = "time",
    y = "amount",
    color = "fruit",
    hover_data={"time": "|%Y年%m月"}
)
fig5.update_layout(
    xaxis_tickangle = 45,
    xaxis_tickformat = "%Y-%m",
    yaxis_tickformat = "0"
)

fig5.show()

# %%
# 不同地区的销量
df7 = pd.pivot_table(
    df,
    index=[pd.Grouper(key="time", freq="Y"), "region"],
    values="kilogram",
    aggfunc=np.sum
).reset_index()
df7["time"] = df7["time"].dt.strftime("%Y")


df7
# Out:
#     time region  kilogram
# 0   2019     华中      6749
# 1   2019     华北      6111
# 2   2019     华南      6316
# 3   2019     西北      7945
# 4   2020     华中      6436
# 5   2020     华北      6692
# 6   2020     华南      6585
# 7   2020     西北      7201
# 8   2021     华中      6966
# 9   2021     华北      5534
# 10  2021     华南      7336
# 11  2021     西北      7758

# %%
fig6 = px.bar(
    df7,
    x = "region",
    y = "kilogram",
    color="region",
    facet_col="time",
    text = "kilogram"
)

fig6.show()

# %%
# 不同地区年度平均销售额
df8 = pd.pivot_table(
    df,
    index=[pd.Grouper(key="time", freq="Y"), "region"],
    values="amount",
    aggfunc=np.mean
).reset_index()

df8["time"] = df8["time"].dt.strftime("%Y")
df8["time"] = df8["time"].astype("int")
df8.style.background_gradient(cmap="Spectral_r")
# Out:
# <style type="text/css">
# #T_2b8f3_row0_col0, #T_2b8f3_row1_col0, #T_2b8f3_row2_col0, #T_2b8f3_row2_col2, #T_2b8f3_row3_col0, #T_2b8f3_row10_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_2b8f3_row0_col2 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_2b8f3_row1_col2, #T_2b8f3_row5_col2 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_2b8f3_row3_col2, #T_2b8f3_row11_col2 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_2b8f3_row4_col0, #T_2b8f3_row5_col0, #T_2b8f3_row6_col0, #T_2b8f3_row7_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_2b8f3_row4_col2 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_2b8f3_row6_col2 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_2b8f3_row7_col2, #T_2b8f3_row8_col0, #T_2b8f3_row9_col0, #T_2b8f3_row10_col0, #T_2b8f3_row11_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_2b8f3_row8_col2 {
#   background-color: #9cd7a4;
#   color: #000000;
# }
# #T_2b8f3_row9_col2 {
#   background-color: #caea9e;
#   color: #000000;
# }
# </style>
# <table id="T_2b8f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >time</th>
#       <th class="col_heading level0 col1" >region</th>
#       <th class="col_heading level0 col2" >amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b8f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b8f3_row0_col0" class="data row0 col0" >2019</td>
#       <td id="T_2b8f3_row0_col1" class="data row0 col1" >华中</td>
#       <td id="T_2b8f3_row0_col2" class="data row0 col2" >506.060870</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b8f3_row1_col0" class="data row1 col0" >2019</td>
#       <td id="T_2b8f3_row1_col1" class="data row1 col1" >华北</td>
#       <td id="T_2b8f3_row1_col2" class="data row1 col2" >547.827500</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b8f3_row2_col0" class="data row2 col0" >2019</td>
#       <td id="T_2b8f3_row2_col1" class="data row2 col1" >华南</td>
#       <td id="T_2b8f3_row2_col2" class="data row2 col2" >319.011765</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b8f3_row3_col0" class="data row3 col0" >2019</td>
#       <td id="T_2b8f3_row3_col1" class="data row3 col1" >西北</td>
#       <td id="T_2b8f3_row3_col2" class="data row3 col2" >1057.407407</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b8f3_row4_col0" class="data row4 col0" >2020</td>
#       <td id="T_2b8f3_row4_col1" class="data row4 col1" >华中</td>
#       <td id="T_2b8f3_row4_col2" class="data row4 col2" >494.366667</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b8f3_row5_col0" class="data row5 col0" >2020</td>
#       <td id="T_2b8f3_row5_col1" class="data row5 col1" >华北</td>
#       <td id="T_2b8f3_row5_col2" class="data row5 col2" >547.335870</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b8f3_row6_col0" class="data row6 col0" >2020</td>
#       <td id="T_2b8f3_row6_col1" class="data row6 col1" >华南</td>
#       <td id="T_2b8f3_row6_col2" class="data row6 col2" >330.255172</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b8f3_row7_col0" class="data row7 col0" >2020</td>
#       <td id="T_2b8f3_row7_col1" class="data row7 col1" >西北</td>
#       <td id="T_2b8f3_row7_col2" class="data row7 col2" >1071.843299</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b8f3_row8_col0" class="data row8 col0" >2021</td>
#       <td id="T_2b8f3_row8_col1" class="data row8 col1" >华中</td>
#       <td id="T_2b8f3_row8_col2" class="data row8 col2" >527.868132</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b8f3_row9_col0" class="data row9 col0" >2021</td>
#       <td id="T_2b8f3_row9_col1" class="data row9 col1" >华北</td>
#       <td id="T_2b8f3_row9_col2" class="data row9 col2" >583.830556</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2b8f3_row10_col0" class="data row10 col0" >2021</td>
#       <td id="T_2b8f3_row10_col1" class="data row10 col1" >华南</td>
#       <td id="T_2b8f3_row10_col2" class="data row10 col2" >319.354082</td>
#     </tr>
#     <tr>
#       <th id="T_2b8f3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2b8f3_row11_col0" class="data row11 col0" >2021</td>
#       <td id="T_2b8f3_row11_col1" class="data row11 col1" >西北</td>
#       <td id="T_2b8f3_row11_col2" class="data row11 col2" >1059.109615</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 用户订单量、金额对比
df9 = pd.pivot_table(
    df,
    index = "name",
    aggfunc={
        "time": "count",
        "amount": "sum"
    }
).reset_index()\
    .rename(columns = {"time": "order_number"})

df9.style.background_gradient(cmap="Spectral_r")
# Out:
# <style type="text/css">
# #T_f355d_row0_col1 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_f355d_row0_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_f355d_row1_col1 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_f355d_row1_col2, #T_f355d_row4_col2 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_f355d_row2_col1 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_f355d_row2_col2 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_f355d_row3_col1, #T_f355d_row3_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_f355d_row4_col1 {
#   background-color: #c6e89f;
#   color: #000000;
# }
# #T_f355d_row5_col1, #T_f355d_row6_col1, #T_f355d_row6_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_f355d_row5_col2 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f355d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >order_number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f355d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f355d_row0_col0" class="data row0 col0" >Jimmy</td>
#       <td id="T_f355d_row0_col1" class="data row0 col1" >99264.000000</td>
#       <td id="T_f355d_row0_col2" class="data row0 col2" >162</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f355d_row1_col0" class="data row1 col0" >John</td>
#       <td id="T_f355d_row1_col1" class="data row1 col1" >95849.100000</td>
#       <td id="T_f355d_row1_col2" class="data row1 col2" >152</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f355d_row2_col0" class="data row2 col0" >Lym</td>
#       <td id="T_f355d_row2_col1" class="data row2 col1" >100757.900000</td>
#       <td id="T_f355d_row2_col2" class="data row2 col2" >157</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f355d_row3_col0" class="data row3 col0" >Michk</td>
#       <td id="T_f355d_row3_col1" class="data row3 col1" >108559.100000</td>
#       <td id="T_f355d_row3_col2" class="data row3 col2" >174</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f355d_row4_col0" class="data row4 col0" >Mike</td>
#       <td id="T_f355d_row4_col1" class="data row4 col1" >98849.000000</td>
#       <td id="T_f355d_row4_col2" class="data row4 col2" >152</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f355d_row5_col0" class="data row5 col0" >Tom</td>
#       <td id="T_f355d_row5_col1" class="data row5 col1" >93745.800000</td>
#       <td id="T_f355d_row5_col2" class="data row5 col2" >150</td>
#     </tr>
#     <tr>
#       <th id="T_f355d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f355d_row6_col0" class="data row6 col0" >xiaoming</td>
#       <td id="T_f355d_row6_col1" class="data row6 col1" >93739.700000</td>
#       <td id="T_f355d_row6_col2" class="data row6 col2" >149</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 用户水果喜好
df10 = pd.pivot_table(
    df,
    index=["name", "fruit"],
    aggfunc={
        "time": "count",
        "amount": "sum" 
    }
).reset_index()\
    .rename(columns={"time": "number"})

df10.sort_values(["name", "number", "amount"], ascending=[True, False, False])
df10.style.bar(subset=["number", "amount"], color = "#a97fcf")
# Out:
# <style type="text/css">
# #T_4a7e5_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 99.1%, transparent 99.1%);
# }
# #T_4a7e5_row0_col3, #T_4a7e5_row28_col3, #T_4a7e5_row30_col3, #T_4a7e5_row32_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 61.9%, transparent 61.9%);
# }
# #T_4a7e5_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 9.6%, transparent 9.6%);
# }
# #T_4a7e5_row1_col3, #T_4a7e5_row10_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 4.8%, transparent 4.8%);
# }
# #T_4a7e5_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 22.9%, transparent 22.9%);
# }
# #T_4a7e5_row2_col3, #T_4a7e5_row8_col3, #T_4a7e5_row14_col2, #T_4a7e5_row16_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 57.1%, transparent 57.1%);
# }
# #T_4a7e5_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 41.2%, transparent 41.2%);
# }
# #T_4a7e5_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 81.0%, transparent 81.0%);
# }
# #T_4a7e5_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 16.2%, transparent 16.2%);
# }
# #T_4a7e5_row4_col3, #T_4a7e5_row9_col3, #T_4a7e5_row27_col3, #T_4a7e5_row38_col3, #T_4a7e5_row39_col3, #T_4a7e5_row40_col3, #T_4a7e5_row46_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 52.4%, transparent 52.4%);
# }
# #T_4a7e5_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 28.0%, transparent 28.0%);
# }
# #T_4a7e5_row5_col3, #T_4a7e5_row7_col3, #T_4a7e5_row21_col3, #T_4a7e5_row36_col3, #T_4a7e5_row37_col3, #T_4a7e5_row44_col3, #T_4a7e5_row50_col3, #T_4a7e5_row53_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 28.6%, transparent 28.6%);
# }
# #T_4a7e5_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 56.7%, transparent 56.7%);
# }
# #T_4a7e5_row6_col3, #T_4a7e5_row11_col3, #T_4a7e5_row14_col3, #T_4a7e5_row20_col3, #T_4a7e5_row33_col3, #T_4a7e5_row42_col3, #T_4a7e5_row47_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 38.1%, transparent 38.1%);
# }
# #T_4a7e5_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 2.4%, transparent 2.4%);
# }
# #T_4a7e5_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 93.2%, transparent 93.2%);
# }
# #T_4a7e5_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 30.4%, transparent 30.4%);
# }
# #T_4a7e5_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 3.4%, transparent 3.4%);
# }
# #T_4a7e5_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 21.1%, transparent 21.1%);
# }
# #T_4a7e5_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 6.0%, transparent 6.0%);
# }
# #T_4a7e5_row12_col3, #T_4a7e5_row34_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 19.0%, transparent 19.0%);
# }
# #T_4a7e5_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 41.5%, transparent 41.5%);
# }
# #T_4a7e5_row13_col3, #T_4a7e5_row15_col3, #T_4a7e5_row19_col3, #T_4a7e5_row24_col3, #T_4a7e5_row54_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 47.6%, transparent 47.6%);
# }
# #T_4a7e5_row15_col2, #T_4a7e5_row26_col3, #T_4a7e5_row44_col2, #T_4a7e5_row45_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 9.5%, transparent 9.5%);
# }
# #T_4a7e5_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 94.4%, transparent 94.4%);
# }
# #T_4a7e5_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 21.9%, transparent 21.9%);
# }
# #T_4a7e5_row17_col3, #T_4a7e5_row18_col3, #T_4a7e5_row31_col3, #T_4a7e5_row43_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 33.3%, transparent 33.3%);
# }
# #T_4a7e5_row18_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 13.8%, transparent 13.8%);
# }
# #T_4a7e5_row19_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 24.9%, transparent 24.9%);
# }
# #T_4a7e5_row20_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 11.1%, transparent 11.1%);
# }
# #T_4a7e5_row21_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 32.7%, transparent 32.7%);
# }
# #T_4a7e5_row22_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 82.1%, transparent 82.1%);
# }
# #T_4a7e5_row22_col3, #T_4a7e5_row29_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 66.7%, transparent 66.7%);
# }
# #T_4a7e5_row23_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 1.2%, transparent 1.2%);
# }
# #T_4a7e5_row23_col3, #T_4a7e5_row35_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 23.8%, transparent 23.8%);
# }
# #T_4a7e5_row24_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 82.4%, transparent 82.4%);
# }
# #T_4a7e5_row25_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 39.4%, transparent 39.4%);
# }
# #T_4a7e5_row25_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 76.2%, transparent 76.2%);
# }
# #T_4a7e5_row26_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 7.9%, transparent 7.9%);
# }
# #T_4a7e5_row27_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 31.3%, transparent 31.3%);
# }
# #T_4a7e5_row28_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 20.8%, transparent 20.8%);
# }
# #T_4a7e5_row29_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 54.2%, transparent 54.2%);
# }
# #T_4a7e5_row30_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 75.2%, transparent 75.2%);
# }
# #T_4a7e5_row31_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 3.2%, transparent 3.2%);
# }
# #T_4a7e5_row32_col2, #T_4a7e5_row55_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 100.0%, transparent 100.0%);
# }
# #T_4a7e5_row33_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 26.2%, transparent 26.2%);
# }
# #T_4a7e5_row34_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 11.6%, transparent 11.6%);
# }
# #T_4a7e5_row35_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 15.6%, transparent 15.6%);
# }
# #T_4a7e5_row36_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 8.1%, transparent 8.1%);
# }
# #T_4a7e5_row37_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 34.1%, transparent 34.1%);
# }
# #T_4a7e5_row38_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 69.5%, transparent 69.5%);
# }
# #T_4a7e5_row39_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 9.3%, transparent 9.3%);
# }
# #T_4a7e5_row40_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 89.6%, transparent 89.6%);
# }
# #T_4a7e5_row41_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 26.1%, transparent 26.1%);
# }
# #T_4a7e5_row41_col3, #T_4a7e5_row48_col3, #T_4a7e5_row49_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 42.9%, transparent 42.9%);
# }
# #T_4a7e5_row42_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 17.3%, transparent 17.3%);
# }
# #T_4a7e5_row43_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#a97fcf 20.1%, transparent 20.1%);
# }
# #T_4a7e5_

# %%
fig7 = px.bar(
    df10,
    x = "fruit", 
    y = "amount",
    facet_col="name",
    color = "number"
)

fig7.update_layout(
    yaxis_tickformat = "0"
)

fig7.show()

# %%
# 用户分层——RFM模型
df11 = pd.pivot_table(
    df,
    index="name",
    aggfunc={
        "fruit": "count",
        "amount": "sum"
    }
).reset_index()\
    .rename(columns={"fruit": "F", "amount": "M"})

df11
# Out:
#        name         M    F
# 0     Jimmy   99264.0  162
# 1      John   95849.1  152
# 2       Lym  100757.9  157
# 3     Michk  108559.1  174
# 4      Mike   98849.0  152
# 5       Tom   93745.8  150
# 6  xiaoming   93739.7  149

# %%
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2022, 1, 14, 15, 9, 58, 551577)

# %%
df["R"] = df["time"].apply(lambda x: (now - x).days)
df.sort_values(["name", "R"], ascending=[False, True])
# Out:
#            time fruit      name  kilogram  price region  amount     R
# 1094 2021-12-30    橙子  xiaoming        50    6.8     华中   340.0    15
# 1093 2021-12-29   哈密瓜  xiaoming        77   15.8     西北  1216.6    16
# 1085 2021-12-21    苹果  xiaoming        64    8.9     华北   569.6    24
# 1084 2021-12-20    香蕉  xiaoming        90    3.8     华南   342.0    25
# 1077 2021-12-13    葡萄  xiaoming        75   12.8     西北   960.0    32
# ...         ...   ...       ...       ...    ...    ...     ...   ...
# 54   2019-02-24    苹果     Jimmy        82    8.9     华北   729.8  1055
# 53   2019-02-23    橙子     Jimmy        94    6.8     华中   639.2  1056
# 46   2019-02-16    苹果     Jimmy        60    8.9     华北   534.0  1063
# 36   2019-02-06    葡萄     Jimmy        68   12.8     西北   870.4  1073
# 11   2019-01-12    橙子     Jimmy        72    6.8     华中   489.6  1098
#
# [1096 rows x 8 columns]

# %%
df12 = pd.pivot_table(
    df,
    index="name",
    values="R",
    aggfunc="min"
).reset_index()

df12
# Out:
#        name   R
# 0     Jimmy  20
# 1      John  19
# 2       Lym  33
# 3     Michk  17
# 4      Mike  14
# 5       Tom  18
# 6  xiaoming  15

# %%
df13 = pd.merge(df11, df12)
df13 = df13[["name", "F", "M", "R"]]
df13.style.background_gradient(cmap = "Spectral_r")
# Out:
# <style type="text/css">
# #T_1dc36_row0_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_1dc36_row0_col2 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_1dc36_row0_col3 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_1dc36_row1_col1, #T_1dc36_row4_col1 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_1dc36_row1_col2 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_1dc36_row1_col3 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_1dc36_row2_col1 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_1dc36_row2_col2 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_1dc36_row2_col3, #T_1dc36_row3_col1, #T_1dc36_row3_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_1dc36_row3_col3 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_1dc36_row4_col2 {
#   background-color: #c6e89f;
#   color: #000000;
# }
# #T_1dc36_row4_col3, #T_1dc36_row5_col2, #T_1dc36_row6_col1, #T_1dc36_row6_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_1dc36_row5_col1 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_1dc36_row5_col3 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_1dc36_row6_col3 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1dc36_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >F</th>
#       <th class="col_heading level0 col2" >M</th>
#       <th class="col_heading level0 col3" >R</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dc36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dc36_row0_col0" class="data row0 col0" >Jimmy</td>
#       <td id="T_1dc36_row0_col1" class="data row0 col1" >162</td>
#       <td id="T_1dc36_row0_col2" class="data row0 col2" >99264.000000</td>
#       <td id="T_1dc36_row0_col3" class="data row0 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1dc36_row1_col0" class="data row1 col0" >John</td>
#       <td id="T_1dc36_row1_col1" class="data row1 col1" >152</td>
#       <td id="T_1dc36_row1_col2" class="data row1 col2" >95849.100000</td>
#       <td id="T_1dc36_row1_col3" class="data row1 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1dc36_row2_col0" class="data row2 col0" >Lym</td>
#       <td id="T_1dc36_row2_col1" class="data row2 col1" >157</td>
#       <td id="T_1dc36_row2_col2" class="data row2 col2" >100757.900000</td>
#       <td id="T_1dc36_row2_col3" class="data row2 col3" >33</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1dc36_row3_col0" class="data row3 col0" >Michk</td>
#       <td id="T_1dc36_row3_col1" class="data row3 col1" >174</td>
#       <td id="T_1dc36_row3_col2" class="data row3 col2" >108559.100000</td>
#       <td id="T_1dc36_row3_col3" class="data row3 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1dc36_row4_col0" class="data row4 col0" >Mike</td>
#       <td id="T_1dc36_row4_col1" class="data row4 col1" >152</td>
#       <td id="T_1dc36_row4_col2" class="data row4 col2" >98849.000000</td>
#       <td id="T_1dc36_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1dc36_row5_col0" class="data row5 col0" >Tom</td>
#       <td id="T_1dc36_row5_col1" class="data row5 col1" >150</td>
#       <td id="T_1dc36_row5_col2" class="data row5 col2" >93745.800000</td>
#       <td id="T_1dc36_row5_col3" class="data row5 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_1dc36_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1dc36_row6_col0" class="data row6 col0" >xiaoming</td>
#       <td id="T_1dc36_row6_col1" class="data row6 col1" >149</td>
#       <td id="T_1dc36_row6_col2" class="data row6 col2" >93739.700000</td>
#       <td id="T_1dc36_row6_col3" class="data row6 col3" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 用户复购周期分析
# 每个用户的购买时间升序
df14 = df[["name", "time"]].sort_values(["name", "time"], ascending=[False, True])
df14
# Out:
#           name       time
# 5     xiaoming 2019-01-06
# 12    xiaoming 2019-01-13
# 15    xiaoming 2019-01-16
# 16    xiaoming 2019-01-17
# 20    xiaoming 2019-01-21
# ...        ...        ...
# 1070     Jimmy 2021-12-06
# 1072     Jimmy 2021-12-08
# 1082     Jimmy 2021-12-18
# 1087     Jimmy 2021-12-23
# 1089     Jimmy 2021-12-25
#
# [1096 rows x 2 columns]

# %%
df15 = df14.groupby("name").shift(1).rename(columns={"time": "time1"})
df15
# Out:
#           time1
# 5           NaT
# 12   2019-01-06
# 15   2019-01-13
# 16   2019-01-16
# 20   2019-01-17
# ...         ...
# 1070 2021-11-26
# 1072 2021-12-06
# 1082 2021-12-08
# 1087 2021-12-18
# 1089 2021-12-23
#
# [1096 rows x 1 columns]

# %%
df16 = pd.concat([df14, df15], axis=1)
df16.dropna(inplace=True)
df16["timedelta"] = df16["time"] - df16["time1"]
df16["timedelta"] = df16["timedelta"].apply(lambda x: x.days)
df16
# Out:
#           name       time      time1  timedelta
# 12    xiaoming 2019-01-13 2019-01-06          7
# 15    xiaoming 2019-01-16 2019-01-13          3
# 16    xiaoming 2019-01-17 2019-01-16          1
# 20    xiaoming 2019-01-21 2019-01-17          4
# 22    xiaoming 2019-01-23 2019-01-21          2
# ...        ...        ...        ...        ...
# 1070     Jimmy 2021-12-06 2021-11-26         10
# 1072     Jimmy 2021-12-08 2021-12-06          2
# 1082     Jimmy 2021-12-18 2021-12-08         10
# 1087     Jimmy 2021-12-23 2021-12-18          5
# 1089     Jimmy 2021-12-25 2021-12-23          2
#
# [1089 rows x 4 columns]

# %%
fig8 = px.bar(
    df16,
    x = "timedelta",
    y = "name",
    orientation="h",
    color = "timedelta",
    color_continuous_scale="spectral_r"
)
fig8.show()

# %%
df16.groupby("name")["timedelta"].agg(["count", "mean"])
# Out:
#           count      mean
# name
# Jimmy       161  6.695652
# John        151  7.218543
# Lym         156  6.884615
# Michk       173  6.277457
# Mike        151  7.231788
# Tom         149  7.181208
# xiaoming    148  7.358108

# %%
fig9 = px.violin(
    df16,
    y = "timedelta",
    color="name"
)

fig9.show()
